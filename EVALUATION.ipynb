# %%
from IPython.display import display, Markdown
display(Markdown("\n".join(open("README.md").readlines())))
# Out:
# # SJf Evaluation Wahl Alumni-Rat
#
#
#
#
#
# *Algorithmus zur eindeutigen Wahlevaluation für den Alumni-Rat der Stiftung Schweizer Jugend forscht anhand der bindenden Diversitätskriterien*
#
#
#
#
#
# (Art. 4 Organisationsreglement des SJf-Alumni-Rates, Version 30.11.2023)
#
#
#
#
#
# #### Ausführen
#
#
#
# `EVALUATION.ipynb`
#
#
#
# Online auführen auf Binder:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/janjoch/sjf-alumniboard-election-algo/HEAD)
#
#
#
# Ansehen auf NBViewer:
#
# [![NBViewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.org/github/janjoch/sjf-alumniboard-election-algo/tree/main/EVALUATION.ipynb)
#
#
#
#
#
# #### Kriterien
#
#
#
# * `A1` Mindestens zwei (2) Personen aus der Deutschschweiz;
#
# * `A2` mindestens eine (1) Person aus der französischen Schweiz;
#
# * `A3` mindestens eine (1) Person aus der italienischen Schweiz. Massgebend ist die Muttersprache.
#
# * `B` Mindestens drei (3) Personen sind zum Zeitpunkt des Amtsantrittes Alumni bzw. Alumnae durch erstmalige Teilnahme am Nationalen Wettbewerb oder ISTF der letzten drei (3) Kalenderjahren.
#
# * `C` Mindestens eine (1) Person hat vor mehr als zehn (10) Jahren erstmals an einem Wettbewerb oder ISTF teilgenommen.
#
# * `D` Maximal zwei (2) Personen sind nicht Alumni bzw. Alumnae von SJf.
#
#
#
#
#
# #### Rohdaten
#
#
#
# Die Ergebnisse der Wahl inkl. Informationen über die erfüllten Diversitätskriterien der Kandidat\*innen sind in der Datei `Wahlergebnisse.docx` im vorgegebenen Format abzulegen. Die hier vorhandene Beispieldatei kann ersetzt werden, oder aber der Dateipfad im Programm angepasst werden.
#
#
#
# Kandidat\*innen mit der selben Anzahl Stimmen sollten beim Erfassen per Los sortiert werden. Der Algorithmus evaluiert bei Stimmengleichheit die Einträge von oben nach unten. (Aus Gründen der Reproduzierbarkeit wurde auf zufällige Auslosung im Algorithmus verzichtet.)
#
#
#
#
#
# #### Algorithmus
#
#
#
#
#
#
#
# 1. Die Kandidat\*innen werden in einer Rangliste nach Anzahl Stimmen sortiert.
#
# 2. Die Kombinationen werden systematisch auf die Erfüllung aller Kriterien geprüft:
#
#
#
#     1. Ränge 1-7
#
#     2. Ränge 1-6+8
#
#     3. Ränge 1-5+7-8
#
#     4. ...
#
#     5. Ränge 2-8
#
#     6. Ränge 1-6+9
#
#     7. Ränge 1-5+8-9
#
#     8. Ränge 1-4+7-9
#
#     9. ...
#
#
#
#
#
# #### Implementierung des Algorithmus
#
#
#
# Der Quellcode ist in der Datei `election_algorithm.py` zu finden. Das Programm wurde ausgiebig getestet, es wird jedoch keine Haftung übernommen. Die generierten Resultate sollten auf Plausibilität geprüft werden!
#
#
#
# Autor: Janosch Jörg (Arbeitsgruppe Alumni-Rat), 2024, [github.com/janjoch](https://github.com/janjoch), [janjo@duck.com](mailto:janjo@duck.com)

# %% [markdown]
# ## Skript

# %% [markdown]
# Um das Programm auszuführen:
#
# 1. Die erste Code-Zelle auswählen und mit `shift`+`enter` ausführen.
# 2. `shift`+`enter` wiederholt drücken, bis alle Zellen ausgeführt sind.

# %%
import election_algorithm as ea

# %%
XLSX_INPUT_PATH = "Wahlergebnisse.xlsx"

elec = ea.ElectionEvaluation(XLSX_INPUT_PATH, verbose=False)
# Out:
# The best compliant combination is found to be:
# Heinrich, Emil, Otto, Martha, Dora, Romeo, Ida

# %% [markdown]
# #### Übersicht

# %%
elec
# Out:
# <style type="text/css">
# #T_aeb90_ .elected {
#   background-color: green;
# }
# #T_aeb90_row0_col0, #T_aeb90_row1_col0, #T_aeb90_row2_col0, #T_aeb90_row3_col0, #T_aeb90_row4_col0, #T_aeb90_row5_col0, #T_aeb90_row6_col0, #T_aeb90_row7_col0, #T_aeb90_row8_col0, #T_aeb90_row9_col0, #T_aeb90_row10_col0, #T_aeb90_row11_col0, #T_aeb90_row12_col0, #T_aeb90_row13_col0, #T_aeb90_row14_col0, #T_aeb90_row15_col0, #T_aeb90_row16_col0, #T_aeb90_row17_col0 {
#   background-color: ;
# }
# #T_aeb90_row0_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_aeb90_row0_col2, #T_aeb90_row0_col3, #T_aeb90_row0_col6, #T_aeb90_row1_col3, #T_aeb90_row1_col4, #T_aeb90_row1_col6, #T_aeb90_row2_col3, #T_aeb90_row2_col4, #T_aeb90_row2_col6, #T_aeb90_row3_col3, #T_aeb90_row3_col4, #T_aeb90_row3_col5, #T_aeb90_row3_col6, #T_aeb90_row3_col7, #T_aeb90_row4_col3, #T_aeb90_row4_col4, #T_aeb90_row4_col6, #T_aeb90_row5_col2, #T_aeb90_row5_col3, #T_aeb90_row5_col6, #T_aeb90_row5_col8, #T_aeb90_row6_col3, #T_aeb90_row6_col4, #T_aeb90_row6_col6, #T_aeb90_row6_col8, #T_aeb90_row7_col3, #T_aeb90_row7_col4, #T_aeb90_row7_col6, #T_aeb90_row7_col8, #T_aeb90_row8_col2, #T_aeb90_row8_col4, #T_aeb90_row8_col5, #T_aeb90_row8_col6, #T_aeb90_row8_col7, #T_aeb90_row9_col3, #T_aeb90_row9_col4, #T_aeb90_row9_col5, #T_aeb90_row9_col6, #T_aeb90_row9_col8, #T_aeb90_row10_col2, #T_aeb90_row10_col3, #T_aeb90_row10_col5, #T_aeb90_row10_col6, #T_aeb90_row10_col7, #T_aeb90_row10_col8, #T_aeb90_row11_col3, #T_aeb90_row11_col4, #T_aeb90_row11_col5, #T_aeb90_row11_col6, #T_aeb90_row11_col8, #T_aeb90_row12_col3, #T_aeb90_row12_col4, #T_aeb90_row12_col5, #T_aeb90_row13_col2, #T_aeb90_row13_col4, #T_aeb90_row13_col6, #T_aeb90_row13_col8, #T_aeb90_row14_col2, #T_aeb90_row14_col4, #T_aeb90_row14_col6, #T_aeb90_row14_col8, #T_aeb90_row15_col2, #T_aeb90_row15_col4, #T_aeb90_row15_col6, #T_aeb90_row15_col8, #T_aeb90_row16_col2, #T_aeb90_row16_col4, #T_aeb90_row16_col6, #T_aeb90_row16_col8, #T_aeb90_row17_col3, #T_aeb90_row17_col4, #T_aeb90_row17_col6, #T_aeb90_row17_col8 {
#   background-color: lightgrey;
# }
# #T_aeb90_row0_col4, #T_aeb90_row0_col5, #T_aeb90_row0_col7, #T_aeb90_row0_col8, #T_aeb90_row1_col2, #T_aeb90_row1_col5, #T_aeb90_row1_col7, #T_aeb90_row1_col8, #T_aeb90_row2_col2, #T_aeb90_row2_col5, #T_aeb90_row2_col7, #T_aeb90_row2_col8, #T_aeb90_row3_col2, #T_aeb90_row3_col8, #T_aeb90_row4_col2, #T_aeb90_row4_col5, #T_aeb90_row4_col7, #T_aeb90_row4_col8, #T_aeb90_row5_col4, #T_aeb90_row5_col5, #T_aeb90_row5_col7, #T_aeb90_row6_col2, #T_aeb90_row6_col5, #T_aeb90_row6_col7, #T_aeb90_row7_col2, #T_aeb90_row7_col5, #T_aeb90_row7_col7, #T_aeb90_row8_col3, #T_aeb90_row8_col8, #T_aeb90_row9_col2, #T_aeb90_row9_col7, #T_aeb90_row10_col4, #T_aeb90_row11_col2, #T_aeb90_row11_col7, #T_aeb90_row12_col2, #T_aeb90_row12_col6, #T_aeb90_row12_col7, #T_aeb90_row12_col8, #T_aeb90_row13_col3, #T_aeb90_row13_col5, #T_aeb90_row13_col7, #T_aeb90_row14_col3, #T_aeb90_row14_col5, #T_aeb90_row14_col7, #T_aeb90_row15_col3, #T_aeb90_row15_col5, #T_aeb90_row15_col7, #T_aeb90_row16_col3, #T_aeb90_row16_col5, #T_aeb90_row16_col7, #T_aeb90_row17_col2, #T_aeb90_row17_col5, #T_aeb90_row17_col7 {
#   background-color: white;
# }
# #T_aeb90_row1_col1 {
#   background-color: #0f2367;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_aeb90_row2_col1 {
#   background-color: #234fa1;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_aeb90_row3_col1 {
#   background-color: #2070b0;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_aeb90_row4_col1 {
#   background-color: #289cc1;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_aeb90_row5_col1 {
#   background-color: #6dc6be;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row6_col1 {
#   background-color: #75c9bd;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row7_col1 {
#   background-color: #87d0ba;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row8_col1 {
#   background-color: #c2e7b4;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row9_col1, #T_aeb90_row10_col1 {
#   background-color: #cfecb3;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row11_col1 {
#   background-color: #d5efb3;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row12_col1, #T_aeb90_row13_col1 {
#   background-color: #e5f5b2;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row14_col1 {
#   background-color: #e9f7b1;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row15_col1, #T_aeb90_row16_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
#   background-color: ;
# }
# #T_aeb90_row17_col1 {
#   background-color: #ffffd9;
#   color: #000000;
#   background-color: ;
# }
# </style>
# <table id="T_aeb90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >candidate_name</th>
#       <th class="col_heading level0 col1" >votes</th>
#       <th class="col_heading level0 col2" >A1</th>
#       <th class="col_heading level0 col3" >A2</th>
#       <th class="col_heading level0 col4" >A3</th>
#       <th class="col_heading level0 col5" >B</th>
#       <th class="col_heading level0 col6" >C</th>
#       <th class="col_heading level0 col7" >D</th>
#       <th class="col_heading level0 col8" >elected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeb90_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_aeb90_row0_col0" class="data row0 col0" >Heinrich</td>
#       <td id="T_aeb90_row0_col1" class="data row0 col1" >60</td>
#       <td id="T_aeb90_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_aeb90_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_aeb90_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_aeb90_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_aeb90_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_aeb90_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_aeb90_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb90_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_aeb90_row1_col0" class="data row1 col0" >Emil</td>
#       <td id="T_aeb90_row1_col1" class="data row1 col1" >58</td>
#       <td id="T_aeb90_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_aeb90_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_aeb90_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_aeb90_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_aeb90_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_aeb90_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_aeb90_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb90_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_aeb90_row2_col0" class="data row2 col0" >Otto</td>
#       <td id="T_aeb90_row2_col1" class="data row2 col1" >48</td>
#       <td id="T_aeb90_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_aeb90_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_aeb90_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_aeb90_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_aeb90_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_aeb90_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_aeb90_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb90_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_aeb90_row3_col0" class="data row3 col0" >Martha</td>
#       <td id="T_aeb90_row3_col1" class="data row3 col1" >43</td>
#       <td id="T_aeb90_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_aeb90_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_aeb90_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_aeb90_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_aeb90_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_aeb90_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_aeb90_row3_col8" class="data row3 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_aeb90_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_aeb90_row4_col0" class="data row4 col0"

# %% [markdown]
# #### Details zu evaluierten Kombinationen

# %%
elec.report
# Out:
# <style type="text/css">
# #T_72875_ .elected {
#   background-color: green;
# }
# #T_72875_row0_col0, #T_72875_row0_col1, #T_72875_row1_col0, #T_72875_row1_col1, #T_72875_row2_col0, #T_72875_row2_col1, #T_72875_row3_col0, #T_72875_row3_col1, #T_72875_row4_col0, #T_72875_row4_col1, #T_72875_row5_col0, #T_72875_row5_col1, #T_72875_row6_col0, #T_72875_row6_col1, #T_72875_row7_col0, #T_72875_row7_col1, #T_72875_row8_col0, #T_72875_row8_col1, #T_72875_row9_col0, #T_72875_row9_col1, #T_72875_row10_col0, #T_72875_row10_col1, #T_72875_row11_col0, #T_72875_row11_col1, #T_72875_row12_col0, #T_72875_row12_col1, #T_72875_row13_col0, #T_72875_row13_col1, #T_72875_row14_col0, #T_72875_row14_col1, #T_72875_row15_col0, #T_72875_row15_col1, #T_72875_row16_col0, #T_72875_row16_col1, #T_72875_row17_col0, #T_72875_row17_col1, #T_72875_row18_col0, #T_72875_row18_col1, #T_72875_row19_col0, #T_72875_row19_col1, #T_72875_row20_col0, #T_72875_row20_col1, #T_72875_row21_col0, #T_72875_row21_col1, #T_72875_row22_col0, #T_72875_row22_col1, #T_72875_row23_col0, #T_72875_row23_col1, #T_72875_row24_col0, #T_72875_row24_col1, #T_72875_row25_col0, #T_72875_row25_col1, #T_72875_row26_col0, #T_72875_row26_col1, #T_72875_row27_col0, #T_72875_row27_col1, #T_72875_row28_col0, #T_72875_row28_col1, #T_72875_row29_col0, #T_72875_row29_col1, #T_72875_row30_col0, #T_72875_row30_col1, #T_72875_row31_col0, #T_72875_row31_col1, #T_72875_row32_col0, #T_72875_row32_col1, #T_72875_row33_col0, #T_72875_row33_col1, #T_72