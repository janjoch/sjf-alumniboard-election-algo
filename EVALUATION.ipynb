# %%
from IPython.display import display, Markdown
display(Markdown("\n".join(open("README.md").readlines())))
# Out:
# # SJf Evaluation Wahl Alumni-Rat
#
#
#
#
#
# *Algorithmus zur eindeutigen Wahlevaluation für den Alumni-Rat der Stiftung Schweizer Jugend forscht anhand der bindenden Diversitätskriterien*
#
#
#
#
#
# (Art. 4 Organisationsreglement des SJf-Alumni-Rates, Version 30.11.2023)
#
#
#
#
#
# #### Ausführen
#
#
#
# `EVALUATION.ipynb`
#
#
#
# Online auführen auf Binder:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/janjoch/sjf-alumniboard-election-algo/HEAD)
#
#
#
# Ansehen auf NBViewer:
#
# [![NBViewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://nbviewer.org/github/janjoch/sjf-alumniboard-election-algo/tree/main/EVALUATION.ipynb)
#
#
#
#
#
# #### Kriterien
#
#
#
# * `A1` Mindestens zwei (2) Personen aus der Deutschschweiz;
#
# * `A2` mindestens eine (1) Person aus der französischen Schweiz;
#
# * `A3` mindestens eine (1) Person aus der italienischen Schweiz. Massgebend ist die Muttersprache.
#
# * `B` Mindestens drei (3) Personen sind zum Zeitpunkt des Amtsantrittes Alumni bzw. Alumnae durch erstmalige Teilnahme am Nationalen Wettbewerb oder ISTF der letzten drei (3) Kalenderjahren.
#
# * `C` Mindestens eine (1) Person hat vor mehr als zehn (10) Jahren erstmals an einem Wettbewerb oder ISTF teilgenommen.
#
# * `D` Maximal zwei (2) Personen sind nicht Alumni bzw. Alumnae von SJf.
#
#
#
#
#
# #### Rohdaten
#
#
#
# Die Ergebnisse der Wahl inkl. Informationen über die erfüllten Diversitätskriterien der Kandidat\*innen sind in der Datei `Wahlergebnisse.xlsx` im vorgegebenen Format abzulegen. Die hier vorhandene Beispieldatei kann ersetzt werden, oder der Dateipfad im Programm angepasst werden. Wird das Skript ohne Änderung der Datei ausgeführt, so werden die Musterdaten ausgewertet.
#
#
#
# Kandidat\*innen mit der selben Anzahl Stimmen sollten beim Erfassen per Los sortiert werden. Der Algorithmus evaluiert bei Stimmengleichheit die Einträge von oben nach unten. (Aus Gründen der Reproduzierbarkeit wurde auf zufällige Auslosung im Algorithmus verzichtet.)
#
#
#
#
#
# #### Algorithmus
#
#
#
# ##### Motivation
#
#
#
# Um eine eindeutige beste Zusammensetzung anhand der Diversitätskriterien zu finden, ist eine Gewichtung anhand der Rangliste in Zweierpotenzen unabdingbar. Dabei hat die Person mit den meisten Stimmen Gewicht 1, die nächste 2, die darauffolgende 4, dann 8, usw. Die beste Zusammensetzung *1,2,3,4,5,6,7* hat dann eine gewichtete Summe von 127. Die nächstbeste, *1,2,3,4,5,6,8* zählt 191, dann *1,2,3,4,5,7,8* 223. Je tiefer diese Summe, je besser. Würden lediglich die Anzahl Stimmen aufsummiert, so könnte es zu Stimmengleichheit mehrerer Kombinationen führen. Zudem wäre dies programmatisch weniger eindeutig implementierbar.
#
#
#
#
#
# ##### Ablauf
#
#
#
# 1. Die Kandidat\*innen werden in einer Rangliste nach Anzahl Stimmen sortiert.
#
# 2. Die Kombinationen werden systematisch auf die Erfüllung aller Kriterien geprüft:
#
#
#
#     1. Ränge 1-7
#
#     2. Ränge 1-6+8
#
#     3. Ränge 1-5+7-8
#
#     4. ...
#
#     5. Ränge 2-8
#
#     6. Ränge 1-6+9
#
#     7. Ränge 1-5+8-9
#
#     8. Ränge 1-4+7-9
#
#     9. ...
#
#
#
#
#
# ##### Implementierung des Algorithmus
#
#
#
# Der Quellcode ist in der Datei `election_algorithm.py` zu finden. Das Programm wurde ausgiebig getestet, es wird jedoch keine Garantie übernommen. Die generierten Resultate sollten auf Plausibilität geprüft werden!
#
#
#
# Autor: Janosch Jörg (Arbeitsgruppe Alumni-Rat), 2024, [github.com/janjoch](https://github.com/janjoch), [janjo@duck.com](mailto:janjo@duck.com)

# %% [markdown]
# ## Skript

# %% [markdown]
# Um das Programm auszuführen:
#
# 1. Die erste Code-Zelle auswählen und mit `shift`+`enter` ausführen.
# 2. `shift`+`enter` wiederholt drücken, bis alle Zellen ausgeführt sind.

# %%
import election_algorithm as ea

# %%
XLSX_INPUT_PATH = "Wahlergebnisse.xlsx"

N_MEMBERS = 7
COMPLIANCE_RULES = {
    "A1": lambda x: x >= 2,
    "A2": lambda x: x >= 1,
    "A3": lambda x: x >= 1,
    "B": lambda x: x >= 3,
    "C": lambda x: x >= 1,
    "D": lambda x: ~x <= 2,
}

elec = ea.ElectionEvaluation(
    file_path=XLSX_INPUT_PATH,
    n_members=N_MEMBERS,
    compliance_rules=COMPLIANCE_RULES,
    verbose=False,
)
# Out:
# The best compliant combination is found to be:
# Nina, Heinrich, Otto, Martha, Dora, Paula, Ida

# %% [markdown]
# #### Übersicht

# %%
elec
# Out:
# <style type="text/css">
# #T_85650_ .elected {
#   background-color: green;
# }
# #T_85650_row0_col0, #T_85650_row1_col0, #T_85650_row2_col0, #T_85650_row3_col0, #T_85650_row4_col0, #T_85650_row5_col0, #T_85650_row6_col0, #T_85650_row7_col0, #T_85650_row8_col0, #T_85650_row9_col0, #T_85650_row10_col0, #T_85650_row11_col0, #T_85650_row12_col0, #T_85650_row13_col0, #T_85650_row14_col0, #T_85650_row15_col0, #T_85650_row16_col0, #T_85650_row17_col0 {
#   background-color: ;
# }
# #T_85650_row0_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_85650_row0_col2, #T_85650_row0_col4, #T_85650_row0_col6, #T_85650_row1_col2, #T_85650_row1_col3, #T_85650_row1_col6, #T_85650_row2_col3, #T_85650_row2_col4, #T_85650_row2_col6, #T_85650_row3_col3, #T_85650_row3_col4, #T_85650_row3_col5, #T_85650_row3_col6, #T_85650_row3_col7, #T_85650_row4_col3, #T_85650_row4_col4, #T_85650_row4_col6, #T_85650_row5_col2, #T_85650_row5_col3, #T_85650_row5_col6, #T_85650_row6_col3, #T_85650_row6_col4, #T_85650_row6_col6, #T_85650_row6_col8, #T_85650_row7_col3, #T_85650_row7_col4, #T_85650_row7_col6, #T_85650_row7_col8, #T_85650_row8_col3, #T_85650_row8_col4, #T_85650_row8_col6, #T_85650_row8_col8, #T_85650_row9_col3, #T_85650_row9_col4, #T_85650_row9_col5, #T_85650_row10_col2, #T_85650_row10_col4, #T_85650_row10_col5, #T_85650_row10_col6, #T_85650_row10_col7, #T_85650_row10_col8, #T_85650_row11_col3, #T_85650_row11_col4, #T_85650_row11_col5, #T_85650_row11_col6, #T_85650_row11_col8, #T_85650_row12_col2, #T_85650_row12_col3, #T_85650_row12_col5, #T_85650_row12_col6, #T_85650_row12_col7, #T_85650_row12_col8, #T_85650_row13_col3, #T_85650_row13_col4, #T_85650_row13_col5, #T_85650_row13_col6, #T_85650_row13_col8, #T_85650_row14_col2, #T_85650_row14_col4, #T_85650_row14_col6, #T_85650_row14_col8, #T_85650_row15_col2, #T_85650_row15_col4, #T_85650_row15_col6, #T_85650_row15_col8, #T_85650_row16_col2, #T_85650_row16_col4, #T_85650_row16_col6, #T_85650_row16_col8, #T_85650_row17_col3, #T_85650_row17_col4, #T_85650_row17_col6, #T_85650_row17_col8 {
#   background-color: lightgrey;
# }
# #T_85650_row0_col3, #T_85650_row0_col5, #T_85650_row0_col7, #T_85650_row0_col8, #T_85650_row1_col4, #T_85650_row1_col5, #T_85650_row1_col7, #T_85650_row1_col8, #T_85650_row2_col2, #T_85650_row2_col5, #T_85650_row2_col7, #T_85650_row2_col8, #T_85650_row3_col2, #T_85650_row3_col8, #T_85650_row4_col2, #T_85650_row4_col5, #T_85650_row4_col7, #T_85650_row4_col8, #T_85650_row5_col4, #T_85650_row5_col5, #T_85650_row5_col7, #T_85650_row5_col8, #T_85650_row6_col2, #T_85650_row6_col5, #T_85650_row6_col7, #T_85650_row7_col2, #T_85650_row7_col5, #T_85650_row7_col7, #T_85650_row8_col2, #T_85650_row8_col5, #T_85650_row8_col7, #T_85650_row9_col2, #T_85650_row9_col6, #T_85650_row9_col7, #T_85650_row9_col8, #T_85650_row10_col3, #T_85650_row11_col2, #T_85650_row11_col7, #T_85650_row12_col4, #T_85650_row13_col2, #T_85650_row13_col7, #T_85650_row14_col3, #T_85650_row14_col5, #T_85650_row14_col7, #T_85650_row15_col3, #T_85650_row15_col5, #T_85650_row15_col7, #T_85650_row16_col3, #T_85650_row16_col5, #T_85650_row16_col7, #T_85650_row17_col2, #T_85650_row17_col5, #T_85650_row17_col7 {
#   background-color: white;
# }
# #T_85650_row1_col1 {
#   background-color: #0f2367;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_85650_row2_col1 {
#   background-color: #2258a5;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_85650_row3_col1 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_85650_row4_col1 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
#   background-color: ;
# }
# #T_85650_row5_col1 {
#   background-color: #73c8bd;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row6_col1 {
#   background-color: #7acbbc;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row7_col1 {
#   background-color: #8ed3ba;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row8_col1 {
#   background-color: #97d6b9;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row9_col1 {
#   background-color: #bde5b5;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row10_col1 {
#   background-color: #c6e9b4;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row11_col1, #T_85650_row12_col1 {
#   background-color: #d1edb3;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row13_col1 {
#   background-color: #d6efb3;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row14_col1 {
#   background-color: #e6f5b2;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row15_col1, #T_85650_row16_col1 {
#   background-color: #f8fcca;
#   color: #000000;
#   background-color: ;
# }
# #T_85650_row17_col1 {
#   background-color: #ffffd9;
#   color: #000000;
#   background-color: ;
# }
# </style>
# <table id="T_85650_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >candidate_name</th>
#       <th class="col_heading level0 col1" >votes</th>
#       <th class="col_heading level0 col2" >A1</th>
#       <th class="col_heading level0 col3" >A2</th>
#       <th class="col_heading level0 col4" >A3</th>
#       <th class="col_heading level0 col5" >B</th>
#       <th class="col_heading level0 col6" >C</th>
#       <th class="col_heading level0 col7" >D</th>
#       <th class="col_heading level0 col8" >elected</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85650_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_85650_row0_col0" class="data row0 col0" >Nina</td>
#       <td id="T_85650_row0_col1" class="data row0 col1" >62</td>
#       <td id="T_85650_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_85650_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_85650_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_85650_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_85650_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_85650_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_85650_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_85650_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_85650_row1_col0" class="data row1 col0" >Heinrich</td>
#       <td id="T_85650_row1_col1" class="data row1 col1" >60</td>
#       <td id="T_85650_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_85650_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_85650_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_85650_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_85650_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_85650_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_85650_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_85650_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_85650_row2_col0" class="data row2 col0" >Otto</td>
#       <td id="T_85650_row2_col1" class="data row2 col1" >48</td>
#       <td id="T_85650_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_85650_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_85650_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_85650_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_85650_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_85650_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_85650_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_85650_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_85650_row3_col0" class="data row3 col0" >Martha</td>
#       <td id="T_85650_row3_col1" class="data row3 col1" >43</td>
#       <td id="T_85650_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_85650_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_85650_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_85650_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_85650_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_85650_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_85650_row3_col8" class="data row3 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_85650_level0_row4" class="row_heading leve

# %% [markdown]
# #### Details zu evaluierten Kombinationen

# %%
elec.report
# Out:
# <style type="text/css">
# #T_f083d_ .elected {
#   background-color: green;
# }
# #T_f083d_row0_col0, #T_f083d_row0_col1, #T_f083d_row1_col0, #T_f083d_row1_col1, #T_f083d_row2_col0, #T_f083d_row2_col1, #T_f083d_row3_col0, #T_f083d_row3_col1, #T_f083d_row4_col0, #T_f083d_row4_col1, #T_f083d_row5_col0, #T_f083d_row5_col1, #T_f083d_row6_col0, #T_f083d_row6_col1, #T_f083d_row7_col0, #T_f083d_row7_col1, #T_f083d_row8_col0, #T_f083d_row8_col1, #T_f083d_row9_col0, #T_f083d_row9_col1, #T_f083d_row10_col0, #T_f083d_row10_col1, #T_f083d_row11_col0, #T_f083d_row11_col1, #T_f083d_row12_col0, #T_f083d_row12_col1, #T_f083d_row13_col0, #T_f083d_row13_col1, #T_f083d_row14_col0, #T_f083d_row14_col1, #T_f083d_row15_col0, #T_f083d_row15_col1, #T_f083d_row16_col0, #T_f083d_row16_col1, #T_f083d_row17_col0, #T_f083d_row17_col1, #T_f083d_row18_